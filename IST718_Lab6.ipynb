# %% [markdown]
# <a href="https://colab.research.google.com/github/LaTran01/IST718_Lab/blob/Lab6_Housing/IST718_Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Predictive Model for Sustainable Products (Python)

# import packages for analysis and modeling
import pandas as pd  # data frame operations

import numpy as np  # arrays and math functions
from scipy.stats import uniform  # for training-and-test split
import statsmodels.api as sm  # statistical models (including regression)
import statsmodels.formula.api as smf  # R-like model specification
import matplotlib.pyplot as plt  # 2D plotting
import tensorflow as tf

import seaborn as sns  # PROVIDES TRELLIS AND SMALL MULTIPLE PLOTTING
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv('https://raw.githubusercontent.com/2SUBDA/IST_718/master/Zip_Zhvi_SingleFamilyResidence_20.csv')
print(df.StateName.unique())
#df.columns.map(type)

df.describe(include="all")
# Out:
# ['OH' 'AR' 'NY' 'KY' 'OK' 'WV' 'MO' 'SC' 'FL' 'IL' 'GA' 'AL' 'PA' 'TN'
#  'CO' 'LA' 'AZ' 'IA' 'MI' 'MD' 'CA' 'NC' 'IN' 'NJ' 'VA' 'ME' 'TX' 'WI'
#  'VT' 'KS' 'MN' 'MA' 'SD' 'WA' 'NE' 'OR' 'NH' 'DE' 'CT' 'ID' 'RI' 'NV'
#  'UT' 'AK' 'DC' 'HI' 'NM' 'ND' 'MS' 'MT' 'WY']
#              RegionID      SizeRank    RegionName RegionType StateName  State  \
# count    15408.000000  15408.000000  15408.000000      15408     15408  15408
# unique            NaN           NaN           NaN          1        51     51
# top               NaN           NaN           NaN        Zip        NY     NY
# freq              NaN           NaN           NaN      15408      1483   1483
# mean     79620.636488  10153.479102  45350.862863        NaN       NaN    NaN
# std      31172.628038   8001.290088  29698.755549        NaN       NaN    NaN
# min      58004.000000      0.000000    602.000000        NaN       NaN    NaN
# 25%      65792.750000   3885.750000  19115.750000        NaN       NaN    NaN
# ...
